# %% [markdown]
# <a href="https://colab.research.google.com/github/rutuja6201/DATA/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data=pd.read_csv("rutuja.csv")
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-da60963264f2> in <cell line: 1>()
# ----> 1 data=pd.read_csv("rutuja.csv")
#       2 data
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
data1=pd.read_excel("rutuja1.xlsx")
data
# Out:
#    Roll no       Name div class
# 0      6201    rutuja   B  SYIT
# 1      6202    ankita   B  SYIT
# 2      6203    sakshi   B  SYIT
# 3      6204   bhumika   B  SYIT
# 4      6205    saniya   B  SYIT
# 5      6206  prithvee   B  SYIT
# 6      6207      riya   B  SYIT
# 7      6208    sanika   B  SYIT
# 8      6209   chimaya   B  SYIT
# 9      6210     mansi   b  SYIT

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mping

# %%
img=mping.imread("india flag.jpg")
plt.imshow(img)

# %% [markdown]
# Summarizing data with statistics

# %%
df=pd.DataFrame({'roll.no':[102,102,103,104,105],'name':['saniya','saniya','rutuja','sakshi','prithvi'],'marks':[50,50,70,56,40],'Class':['A','A','B','B','B']})
df
# Out:
#    roll.no     name  marks Class
# 0      102   saniya     50     A
# 1      102   saniya     50     A
# 2      103   rutuja     70     B
# 3      104   sakshi     56     B
# 4      105  prithvi     40     B

# %%
df.isnull()
# Out:
#    roll.no   name  marks  Class
# 0    False  False  False  False
# 1    False  False  False  False
# 2    False  False  False  False
# 3    False  False  False  False
# 4    False  False  False  False

# %%
df.isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of    roll.no   name  marks  Class
# 0    False  False  False  False
# 1    False  False  False  False
# 2    False  False  False  False
# 3    False  False  False  False
# 4    False  False  False  False>

# %%
df.describe()
# Out:
#          roll.no      marks
# count    5.00000   5.000000
# mean   103.20000  53.200000
# std      1.30384  11.009087
# min    102.00000  40.000000
# 25%    102.00000  50.000000
# 50%    103.00000  50.000000
# 75%    104.00000  56.000000
# max    105.00000  70.000000

# %%
df.count()
# Out:
# roll.no    5
# name       5
# marks      5
# Class      5
# dtype: int64

# %%
df.describe(include="object")
# Out:
#           name Class
# count        5     5
# unique       4     2
# top     saniya     B
# freq         2     3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   roll.no  5 non-null      int64
#  1   name     5 non-null      object
#  2   marks    5 non-null      int64
#  3   Class    5 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 288.0+ bytes

# %%
df.nunique()
# Out:
# roll.no    4
# name       4
# marks      4
# Class      2
# dtype: int64

# %%
df.duplicated()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df['name'].duplicated()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# Name: name, dtype: bool

# %%
df.value_counts()
# Out:
# roll.no  name     marks  Class
# 102      saniya   50     A        2
# 103      rutuja   70     B        1
# 104      sakshi   56     B        1
# 105      prithvi  40     B        1
# dtype: int64

# %%
df['name'].value_counts()
# Out:
# saniya     2
# rutuja     1
# sakshi     1
# prithvi    1
# Name: name, dtype: int64

# %%
df['Class'].value_counts()
# Out:
# B    3
# A    2
# Name: Class, dtype: int64

# %%
df['marks'].mean()
# Out:
# 53.2

# %%
df['marks'].var()
# Out:
# 121.19999999999999

# %%
cor=df.corr()
# Out:
# <ipython-input-78-48d031cc9737>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor=df.corr()

# %%
import seaborn as sns

# %%
sns.heatmap(cor,annot=True,fmt="2f",cmap="cividis")
# Out:
# <Axes: >

# %%
cor
